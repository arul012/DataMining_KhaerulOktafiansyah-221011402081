# %% [markdown]
# <a href="https://colab.research.google.com/github/arul012/DataMining_KhaerulOktafiansyah-221011402081/blob/main/PERTEMUAN_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
subscribers = pd.read_csv("Subscribers.csv")

# %%
subscribers
# Out:
#     ACTIVATION_DATE  ALL_SUBSCRIBERS
# 0        01-05-2020             7131
# 1        02-05-2020             6668
# 2        03-05-2020             4155
# 3        04-05-2020             5979
# 4        05-05-2020             5835
# ..              ...              ...
# 200      17-11-2020             5146
# 201      18-11-2020             4958
# 202      19-11-2020             4857
# 203      20-11-2020             5137
# 204      21-11-2020             4748
#
# [205 rows x 2 columns]

# %%
url = "https://drive.google.com/uc?export=download&id=16tllhqm_L7UFbAdykPKjpXVBCOS27nY6"
df = pd.read_csv(url)

# %%
df
# Out:
#     ACTIVATION_DATE  ALL_SUBSCRIBERS
# 0        01-05-2020             7131
# 1        02-05-2020             6668
# 2        03-05-2020             4155
# 3        04-05-2020             5979
# 4        05-05-2020             5835
# ..              ...              ...
# 200      17-11-2020             5146
# 201      18-11-2020             4958
# 202      19-11-2020             4857
# 203      20-11-2020             5137
# 204      21-11-2020             4748
#
# [205 rows x 2 columns]
